# %% [markdown]
# # Mapa Interativo de PM2.5 por Pais

# %%
import sys
sys.path.append('..')

from src.data.load_data import pipeline_completo, carregar_geometrias_paises
from src.visualization.graficos import gerar_mapa_pm25

pm25, snapshot = pipeline_completo()
geometrias = carregar_geometrias_paises()
gerar_mapa_pm25(geometrias, snapshot, '../reports/figures/mapa_pm25.html')
print('Mapa salvo em reports/figures/mapa_pm25.html, abra num navegador para ver')

# %% [markdown]
# ## Conclusoes
#
# O mapa coropletico da uma visao geografica imediata de onde a qualidade do ar e pior, util pra priorizar politica publica por regiao sem precisar ler tabela.
#
# Isso encerra a analise do projeto. O relatorio final consolida os resultados em `reports/relatorio_final.md`.
